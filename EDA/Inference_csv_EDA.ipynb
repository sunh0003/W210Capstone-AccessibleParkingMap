# %%
# %pwd
# Out:
# 'C:\\Users\\rn0610\\Desktop\\P_folder\\P_W210Capstone\\finalcsv'

# %%
import os
total_csv = os.listdir('C:\\Users\\rn0610\\Desktop\\P_folder\\P_W210Capstone\\finalcsv')
zipcode=[]
for i in total_csv:
    if i.endswith('csv'):
        zipcode.append(i.replace('.csv',''))
zipcode
#len(zipcode)
# Out:
# ['80002',
#  '80010',
#  '80110',
#  '80111',
#  '80113',
#  '80202',
#  '80203',
#  '80204',
#  '80205',
#  '80206',
#  '80207',
#  '80209',
#  '80210',
#  '80211',
#  '80212',
#  '80214',
#  '80216',
#  '80218',
#  '80219',
#  '80220',
#  '80221',
#  '80222',
#  '80223',
#  '80224',
#  '80226',
#  '80227',
#  '80230',
#  '80231',
#  '80232',
#  '80235',
#  '80236',
#  '80237',
#  '80238',
#  '80239',
#  '80246',
#  '80247',
#  '80264',
#  '80290']

# %%
import pandas as pd
columns=['imgname','lat','long','angle','class','confidence','xcenter','ycenter','width','hight','zipcode','zipcode2','detect_loc','new_lat','new_long']
df_empty=pd.DataFrame(columns=columns)
for i in range(len(zipcode)):
    df  = pd.read_csv('C:\\Users\\rn0610\\Desktop\\P_folder\\P_W210Capstone\\finalcsv\\'+zipcode[i]+'.csv')
    df_empty = df_empty.append(df, ignore_index=True)
df_empty
# Out:
#                                      imgname        lat        long angle  \
# 0               39.785659--105.0615673-0.jpg  39.785659 -105.061567     0
# 1             39.78381729--105.0553841-0.jpg  39.783817 -105.055384     0
# 2      39.78382613--105.05734070000001-0.jpg  39.783826 -105.057341     0
# 3              39.78848279--105.061603-0.jpg  39.788483 -105.061603     0
# 4              39.78848279--105.061603-0.jpg  39.788483 -105.061603     0
# ...                                      ...        ...         ...   ...
# 92237                                    NaN  39.739115 -105.005143   NaN
# 92238                                    NaN  39.739476 -105.007190   NaN
# 92239                                    NaN  39.742652 -105.010595   NaN
# 92240                                    NaN  39.740728 -105.007210   NaN
# 92241                                    NaN  39.739257 -105.007103   NaN
#
#       class  confidence   xcenter   ycenter     width     hight zipcode  \
# 0         0    0.904877  0.321094  0.465625  0.104687  0.518750   80212
# 1         2    0.681951  0.298438  0.640625  0.021875  0.031250   80212
# 2         0    0.521230  0.441406  0.448438  0.057813  0.365625   80212
# 3         4    0.835923  0.407031  0.545313  0.035937  0.037500   80212
# 4         2    0.452172  0.848437  0.636719  0.025000  0.042188   80212
# ...     ...         ...       ...       ...       ...       ...     ...
# 92237     5         NaN       NaN       NaN       NaN       NaN   80204
# 92238     5         NaN       NaN       NaN       NaN       NaN   80204
# 92239     5         NaN       NaN       NaN       NaN       NaN   80204
# 92240     5         NaN       NaN       NaN       NaN       NaN   80204
# 92241     5         NaN       NaN       NaN       NaN       NaN   80204
#
#       zipcode2 detect_loc    new_lat    new_long
# 0        80002          L  39.785659 -105.061667
# 1        80002          L  39.783817 -105.055484
# 2        80002          C  39.783826 -105.057341
# 3        80002          C  39.788483 -105.061603
# 4        80002          R  39.788483 -105.061503
# ...        ...        ...        ...         ...
# 92237    80290        NaN        NaN         NaN
# 92238    80290        NaN        NaN         NaN
# 92239    80290        NaN        NaN         NaN
# 92240    80290        NaN        NaN         NaN
# 92241    80290        NaN        NaN         NaN
#
# [92242 rows x 15 columns]

# %%
df1 = df_empty[df_empty['imgname'].notnull()]
#80202, 80203, '80264','80290'
df1
# Out:
#                                       imgname        lat        long angle  \
# 0                39.785659--105.0615673-0.jpg  39.785659 -105.061567     0
# 1              39.78381729--105.0553841-0.jpg  39.783817 -105.055384     0
# 2       39.78382613--105.05734070000001-0.jpg  39.783826 -105.057341     0
# 3               39.78848279--105.061603-0.jpg  39.788483 -105.061603     0
# 4               39.78848279--105.061603-0.jpg  39.788483 -105.061603     0
# ...                                       ...        ...         ...   ...
# 92071  39.73143958--105.01928899999999-90.jpg  39.731440 -105.019289    90
# 92072  39.74025271--105.01057720000001-90.jpg  39.740253 -105.010577    90
# 92073         39.74395485--105.0251365-90.jpg  39.743955 -105.025137    90
# 92074          39.73053788--105.033289-90.jpg  39.730538 -105.033289    90
# 92075         39.74034077--105.0364632-90.jpg  39.740341 -105.036463    90
#
#       class  confidence   xcenter   ycenter     width     hight zipcode  \
# 0         0    0.904877  0.321094  0.465625  0.104687  0.518750   80212
# 1         2    0.681951  0.298438  0.640625  0.021875  0.031250   80212
# 2         0    0.521230  0.441406  0.448438  0.057813  0.365625   80212
# 3         4    0.835923  0.407031  0.545313  0.035937  0.037500   80212
# 4         2    0.452172  0.848437  0.636719  0.025000  0.042188   80212
# ...     ...         ...       ...       ...       ...       ...     ...
# 92071     3    0.503028  0.488281  0.571875  0.020313  0.031250   80204
# 92072     0    0.677891  0.551562  0.529688  0.046875  0.121875   80204
# 92073     0    0.770996  0.487500  0.521875  0.040625  0.296875   80204
# 92074     0    0.828780  0.697656  0.372656  0.089063  0.689062   80204
# 92075     0    0.716447  0.746094  0.532031  0.045312  0.176563   80204
#
#       zipcode2 detect_loc    new_lat    new_long
# 0        80002          L  39.785659 -105.061667
# 1        80002          L  39.783817 -105.055484
# 2        80002          C  39.783826 -105.057341
# 3        80002          C  39.788483 -105.061603
# 4        80002          R  39.788483 -105.061503
# ...        ...        ...        ...         ...
# 92071    80290          C  39.731440 -105.019289
# 92072    80290          C  39.740253 -105.010577
# 92073    80290          C  39.743955 -105.025137
# 92074    80290          R  39.730438 -105.033289
# 92075    80290          R  39.740241 -105.036463
#
# [79954 rows x 15 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns

zip_count = df1['zipcode2'].value_counts().sort_index()
# city_count = city_count[:10,]
plt.figure(figsize=(10,5))
chart = sns.barplot(zip_count.index, zip_count.values, alpha=0.8)
plt.title('Count of zipcode')
plt.ylabel('Number of Occurrences', fontsize=12)
plt.xlabel('zipcode', fontsize=12)
chart.set_xticklabels(chart.get_xticklabels(), rotation=45)
plt.show()
#80205 80202 are downtown

# %% [markdown]
# # Confidence level distribution for different classes

# %%
classes=['lamp','signh','fh','nonpark','stop']
for i in range(5):
    cls = df1[df1['class']==i]['confidence'].value_counts(bins=25).sort_index()
    plt.figure(figsize=(10,5))
    chart = sns.barplot(cls.index, cls.values, alpha=0.8)
    plt.title('distribution of confidence '+classes[i])
    plt.ylabel('Number of Occurrences', fontsize=12)
    plt.xlabel(classes[i]+' confidence', fontsize=12)
    chart.set_xticklabels(chart.get_xticklabels(), rotation=90)
plt.show()

# %% [markdown]
# # Classes occurance distribution for different zipcode

# %%
classes=['lamp','signh','fh','nonpark','stop']
for i in range(5):
    cls = df1[df1['class']==i]['zipcode2'].value_counts().sort_index()
    plt.figure(figsize=(10,5))
    chart = sns.barplot(cls.index, cls.values, alpha=0.8)
    plt.title(classes[i]+' zipcode distribution')
    plt.ylabel('Number of Occurrences', fontsize=12)
    plt.xlabel(classes[i]+' zipcode distribution', fontsize=12)
    chart.set_xticklabels(chart.get_xticklabels(), rotation=90)
plt.show()

# %% [markdown]
# # Make list for signh to plot signh user friendly area

# %%
cls_signh = df1[df1['class']==1]['zipcode2'].value_counts().sort_index()
normalized_df=(cls_signh-cls_signh.min())/(cls_signh.max()-cls_signh.min())
df_concat = pd.concat([cls_signh, normalized_df], axis=1)
df_concat.columns=['num_signh','normalized_num_signh']
df_concat.to_csv('signh_zipcode_2.csv')
